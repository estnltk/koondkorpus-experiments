# %% [markdown]
# # Create a list of all the tokens in the corpora
# ## From koondkorpus zip file using EstNLTK 1.4
#
# Download the following files to the folder `corpora`.
#   * http://ats.cs.ut.ee/keeletehnoloogia/estnltk/koond.zip
#   * http://www.cl.ut.ee/korpused/segakorpus/slohtuleht/failid/xml/SLOleht.tar.gz
#
# Run
# ```bash
# tar -xzf corpora/SLOleht.tar.gz
# tar -xzf corpora/koond.zip
# mv corpora/SLOleht corpora/SLOleht_xml
# mkdir corpora/SLOleht
# python estnltk/estnltk/examples/convert_koondkorpus.py corpora/SLOleht_xml/ corpora/SLOleht/ -e utf_8
# python koondkorpus-experiments/extract_tokens.py corpora/koond corpora/SLOleht --out corpora
# ```
# Find the output files from the folder `corpora`.
#
#
# | corpora     | files  | size     |
# |-------------|--------|----------|
# | koond       | 527730 |   1.8 GB |
# | SLOleht_xml |   3314 | 429.8 MB |
# | SLOleht     |        |          |
#
#
#
#
# ### Additional information
# https://estnltk.github.io/estnltk/1.4.1/tutorials/tei.html
#
# ## From koondkorpus PostgreSQL collection using EstNLTK 1.6

# %%
import sys; sys.path = ["/home/liisi/Documents/estnltk/est1.6"] + sys.path

# %%
from estnltk.storage import PostgresStorage

storage = PostgresStorage(pgpass_file='~/.pgpass',
                          dbname='estonian-text-corpora',
                          schema='estonian_text_corpora',
                          role='estonian_text_corpora_create')

collection = storage.get_collection('test_korpus_2')
# Out:
# INFO:db.py:1164: connecting to host: 'postgres.keeleressursid.ee', port: '5432', dbname: 'estonian-text-corpora', user: 'liisitor'
# INFO:db.py:1176: role: 'estonian_text_corpora_create'

# %%
counter = collection.count_values(layer='words', attr='text', progressbar='notebook')
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
counter.most_common(10)
# Out:
# [('.', 2613),
#  (',', 2580),
#  ('on', 852),
#  ('ja', 837),
#  ('et', 380),
#  ('"', 358),
#  ('ka', 284),
#  ('ei', 261),
#  ('kui', 222),
#  ('(', 201)]

# %%
words = ' '.join(sorted(counter))

# %%
from estnltk.taggers import PronounTypeTagger
from estnltk import Text

tagger = PronounTypeTagger()
tagger
# Out:
# PronounTypeTagger()

# %%
wordst = Text(words).tag_layer()
tagger.tag(wordst)
words2 = wordst['pronoun_type']
#words2

# %%
from collections import defaultdict

meow = defaultdict(list)

for token, form, lemma, postag, ptype in zip(words2.text, words2.form, words2.lemma, words2.partofspeech, words2.pronoun_type):   
    if postag[0]  == 'P':
        for i in range(len(form)):
            meow[token].append([lemma[i], postag[i], form[i], ptype[i]])

# %%
sorted(meow.items())
# Out:
# [('Enda', [['ise', 'P', 'sg g', ('pos', 'det', 'refl')]]),
#  ('Iga', [['iga', 'P', 'sg n', ('det',)]]),
#  ('Igaks', [['iga', 'P', 'sg tr', ('det',)]]),
#  ('Igal', [['iga', 'P', 'sg ad', ('det',)]]),
#  ('Ise',
#   [['ise', 'P', 'pl n', ('pos', 'det', 'refl')],
#    ['ise', 'P', 'sg n', ('pos', 'det', 'refl')]]),
#  ('Keegi', [['keegi', 'P', 'sg n', ('indef',)]]),
#  ('Kel', [['kes', 'P', 'sg ad', ('inter_rel',)]]),
#  ('Kelle',
#   [['kes', 'P', 'pl g', ('inter_rel',)],
#    ['kes', 'P', 'sg g', ('inter_rel',)]]),
#  ('Kellega',
#   [['kes', 'P', 'pl kom', ('inter_rel',)],
#    ['kes', 'P', 'sg kom', ('inter_rel',)]]),
#  ('Kellele',
#   [['kes', 'P', 'pl all', ('inter_rel',)],
#    ['kes', 'P', 'sg all', ('inter_rel',)]]),
#  ('Kes',
#   [['kes', 'P', 'pl n', ('inter_rel',)],
#    ['kes', 'P', 'sg n', ('inter_rel',)]]),
#  ('Kõigi', [['kõik', 'P', 'pl g', ('det',)]]),
#  ('Kõigil', [['kõik', 'P', 'pl ad', ('det',)]]),
#  ('Kõigis', [['kõik', 'P', 'pl in', ('det',)]]),
#  ('Kõik', [['kõik', 'P', 'pl n', ('det',)], ['kõik', 'P', 'sg n', ('det',)]]),
#  ('Ma', [['mina', 'P', 'sg n', ('ps1',)]]),
#  ('Me', [['mina', 'P', 'pl n', ('ps1',)]]),
#  ('Meie', [['mina', 'P', 'pl g', ('ps1',)]]),
#  ('Meiegi', [['mina', 'P', 'pl g', ('ps1',)]]),
#  ('Meil', [['mina', 'P', 'pl ad', ('ps1',)]]),
#  ('Meile', [['mina', 'P', 'pl all', ('ps1',)]]),
#  ('Mida',
#   [['mis', 'P', 'pl p', ('inter_rel',)],
#    ['mis', 'P', 'sg p', ('inter_rel',)]]),
#  ('Midagi', [['miski', 'P', 'sg p', ('inter_rel',)]]),
#  ('Mille',
#   [['mis', 'P', 'pl g', ('inter_rel',)],
#    ['mis', 'P', 'sg g', ('inter_rel',)]]),
#  ('Milline', [['milline', 'P', 'sg n', ('rel',)]]),
#  ('Millisena', [['milline', 'P', 'sg es', ('rel',)]]),
#  ('Mina', [['mina', 'P', 'sg n', ('ps1',)]]),
#  ('Mingi', [['mingi', 'P', 'sg n', ('indef',)]]),
#  ('Minu', [['mina', 'P', 'sg g', ('ps1',)]]),
#  ('Minule', [['mina', 'P', 'sg all', ('ps1',)]]),
#  ('Mis',
#   [['mis', 'P', 'pl n', ('inter_rel',)],
#    ['mis', 'P', 'sg n', ('inter_rel',)]]),
#  ('Mitme', [['mitu', 'P', 'sg g', ('indef',)]]),
#  ('Mitmedki', [['mitu', 'P', 'pl n', ('indef',)]]),
#  ('Mitmel', [['mitu', 'P', 'sg ad', ('indef',)]]),
#  ('Mitu', [['mitu', 'P', 'sg n', ('indef',)]]),
#  ('Mul', [['mina', 'P', 'sg ad', ('ps1',)]]),
#  ('Mulle', [['mina', 'P', 'sg all', ('ps1',)]]),
#  ('Mõlemad', [['mõlema', 'P', 'pl n', ('det',)]]),
#  ('Mõlemas', [['mõlema', 'P', 'sg in', ('det',)]]),
#  ('Mõne', [['mõni', 'P', 'sg g', ('indef',)]]),
#  ('Mõned', [['mõni', 'P', 'pl n', ('indef',)]]),
#  ('Mõnelegi', [['mõni', 'P', 'sg all', ('indef',)]]),
#  ('Mõni', [['mõni', 'P', 'sg n', ('indef',)]]),
#  ('Nad', [['tema', 'P', 'pl n', ('ps3',)]]),
#  ('Need', [['see', 'P', 'pl n', ('dem',)]]),
#  ('Neid', [['see', 'P', 'pl p', ('dem',)]]),
#  ('Neile', [['see', 'P', 'pl all', ('dem',)]]),
#  ('Neist', [['see', 'P', 'pl el', ('dem',)]]),
#  ('Nemad', [['tema', 'P', 'pl n', ('ps3',)]]),
#  ('Nende', [['tema', 'P', 'pl g', ('ps3',)]]),
#  ('Nendes', [['see', 'P', 'pl in', ('dem',)]]),
#  ('Oma', [['oma', 'P', 'sg g', ('pos', 'det', 'refl')]]),
#  ('Paljud', [['palju', 'P', 'pl n', ('indef',)]]),
#  ('Paljudes', [['palju', 'P', 'pl in', ('indef',)]]),
#  ('Sa', [['sina', 'P', 'sg n', ('ps2',)]]),
#  ('Sama', [['sama', 'P', 'sg g', ('dem',)]]),
#  ('Samal', [['sama', 'P', 'sg ad', ('dem',)]]),
#  ('Samasugusest', [['samasugune', 'P', 'sg el', ('dem',)]]),
#  ('Samu', [['sama', 'P', 'pl p', ('dem',)]]),
#  ('Seda', [['see', 'P', 'sg p', ('dem',)]]),
#  ('See', [['see', 'P', 'sg n', ('dem',)]]),
#  ('Sel', [['see', 'P', 'sg ad', ('dem',)]]),
#  ('Selle', [['see', 'P', 'sg g', ('dem',)]]),
#  ('Sellega', [['see', 'P', 'sg kom', ('dem',)]]),
#  ('Selleks', [['see', 'P', 'sg tr', ('dem',)]]),
#  ('Sellel', [['see', 'P', 'sg ad', ('dem',)]]),
#  ('Sellele', [['see', 'P', 'sg all', ('dem',)]]),
#  ('Sellelt', [['see', 'P', 'sg abl', ('dem',)]]),
#  ('Selles', [['see', 'P', 'sg in', ('dem',)]]),
#  ('Sellest', [['see', 'P', 'sg el', ('dem',)]]),
#  ('Selline', [['selline', 'P', 'sg n', ('dem',)]]),
#  ('Selliseid', [['selline', 'P', 'pl p', ('dem',)]]),
#  ('Ta', [['tema', 'P', 'sg n', ('ps3',)]]),
#  ('Teda', [['tema', 'P', 'sg p', ('ps3',)]]),
#  ('Teie', [['sina', 'P', 'pl g', ('ps2',)]]),
#  ('Tema', [['tema', 'P', 'sg g', ('ps3',)]]),
#  ('Too', [['too', 'P', 'sg n', ('dem',)]]),
#  ('end', [['ise', 'P', 'sg p', ('pos', 'det', 'refl')]]),
#  ('enda', [['ise', 'P', 'sg g', ('pos', 'det', 'refl')]]),
#  ('endaga', [['ise', 'P', 'sg kom', ('pos', 'det', 'refl')]]),
#  ('endale', [['ise', 'P', 'sg all', ('pos', 'det', 'refl')]]),
#  ('endalt', [['ise', 'P', 'sg abl', ('pos', 'det', 'refl')]]),
#  ('endas', [['ise', 'P', 'sg in', ('pos', 'det', 'refl')]]),
#  ('endast', [['ise', 'P', 'sg el', ('pos', 'det', 'refl')]]),
#  ('endi', [['ise', 'P', 'pl g', ('pos', 'det', 'refl')]]),
#  ('endid', [['ise', 'P', 'pl p', ('pos', 'det', 'refl')]]),
#  ('endile', [['ise', 'P', 'pl all', ('pos', 'det', 'refl')]]),
#  ('enese', [['ise', 'P', 'sg g', ('pos', 'det', 'refl')]]),
#  ('enesele', [['ise', 'P', 'sg all', ('pos', 'det', 'refl')]]),
#  ('eneselt', [['ise', 'P', 'sg abl', ('pos', 'det', 'refl')]]),
#  ('ennast', [['ise', 'P', 'sg p', ('pos', 'det', 'refl')]]),
#  ('iga', [['iga', 'P', 'sg n', ('det',)]]),
#  ('igal', [['iga', 'P', 'sg ad', ('det',)]]),
#  ('igale', [['iga', 'P', 'sg all', ('det',)]]),
#  ('igas', [['iga', 'P', 'sg in', ('det',)]]),
#  ('igasse', [['iga', 'P', 'sg ill', ('det',)]]),
#  ('igast', [['iga', 'P', 'sg el', ('det',)]]),
#  ('igasugune', [['igasugune', 'P', 'sg n', ('dem',)]]),
#  ('igasugused', [['igasugune', 'P', 'pl n', ('dem',)]]),
#  ('igasuguseid', [['igasugune', 'P', 'pl p', ('dem',)]]),
#  ('igasugusest', [['igasugune', 'P', 'sg el', ('dem',)]]),
#  ('igasuguste', [['igasugune', 'P', 'pl g', ('dem',)]]),
#  ('igasugustes', [['igasugune', 'P', 'pl in', ('dem',)]]),
#  ('igasugustest', [['igasugune', 'P', 'pl el', ('dem',)]]),
#  ('igat', [['iga', 'P', 'sg p', ('det',)]]),
#  ('igaühe', [['igaüks', 'P', 'sg g', ('det',)]]),
#  ('igaühel', [['igaüks', 'P', 'sg ad', ('det',)]]),
#  ('igaüks', [['igaüks', 'P', 'sg n', ('det',)]]),
#  ('ise',
#   [['ise', 'P', 'pl n', ('pos', 'det', 'refl')],
#    ['ise', 'P', 'sg n', ('pos', 'det', 'refl')]]),
#  ('iseenda', [['iseenese', 'P', 'sg g', ('refl',)]]),
#  ('iseendale', [['iseenese', 'P', 'sg all', ('refl',)]]),
#  ('keda',
#   [['kes', 'P', 'pl p', ('inter_rel',)],
#    ['kes', 'P', 'sg p', ('inter_rel',)]]),
#  ('kedagi', [['keegi', 'P', 'sg p', ('indef',)]]),
#  ('keegi', [['keegi', 'P', 'sg n', ('indef',)]]),
#  ('kel', [['kes', 'P', 'sg ad', ('inter_rel',)]]),
#  ('kelle',
#   [['kes', 'P', 'pl g', ('inter_rel',)],
#    ['kes', 'P', 'sg g', ('inter_rel',)]]),
#  ('kelledest', [['kes', 'P', 'pl el', ('inter_rel',)]]),
#  ('kellega',
#   [['kes', 'P', 'pl kom', ('inter_rel',)],
#    ['kes', 'P', 'sg kom', ('inter_rel',)]]),
#  ('kellegagi', [['keegi', 'P', 'sg kom', ('indef',)]]),
#  ('kellegi', [['keegi', 'P', 'sg g', ('indef',)]]),
#  ('kellel',
#   [['kes', 'P', 'pl ad', ('inter_rel',)],
#    ['kes', 'P', 'sg ad', ('inter_rel',)]]),
#  ('kellele',
#   [['kes', 'P', 'pl all', ('inter_rel',)],
#    ['kes', 'P', 'sg all', ('inter_rel',)]]),
#  ('kellelgi', [['keegi', 'P', 'sg ad', ('indef',)]]),
#  ('kelles',
#   [['kes', 'P', 'pl in', ('inter_rel',)],
#    ['kes', 'P', 'sg in', ('inter_rel',)]]),
#  ('kellest',
#   [['kes', 'P', 'pl el', ('inter_rel',)],
#    ['kes', 'P', 'sg el', ('inter_rel',)]]),
#  ('kes',
#   [['kes', 'P', 'pl n', ('inter_rel',)],
#    ['kes', 'P', 'sg n', ('inter_rel',)]]),
#  ('kumb', [['kumb', 'P', 'sg n', ('rel',)]]),
#  ('kumbagi', [['kumbki', 'P', 'sg p', ('det',)]]),
#  ('kumbki', [['kumbki', 'P', 'sg n', ('det',)]]),
#  ('kõigi', [['kõik', 'P', 'pl g', ('det',)]]),
#  ('kõigil', [['kõik', 'P', 'pl ad', ('det',)]]),
#  ('kõigile', [['kõik', 'P', 'pl all', ('det',)]]),
#  ('kõigis', [['kõik', 'P', 'pl in', ('det',)]]),
#  ('kõigisse', [['kõik', 'P', 'pl ill', ('det',)]]),
#  ('kõik', [['kõik', 'P', 'pl n', ('det',)], ['kõik', 'P', 'sg n', ('det',)]]),
#  ('kõike', [['kõik', 'P', 'sg p', ('det',)]]),
#  ('kõiki', [['kõik', 'P', 'pl p', ('det',)]]),
#  ('kõikide', [['kõik', 'P', 'pl g', ('det',)]]),
#  ('kõikidele', [['kõik', 'P', 'pl all', ('det',)]]),
#  ('kõikides', [['kõik', 'P', 'pl in', ('det',)]]),
#  ('ma', [['mina', 'P', 'sg n', ('ps1',)]]),
#  ('me', [['mina', 'P', 'pl g', ('ps1',)]]),
#  ('meid', [['mina', 'P', 'pl p', ('ps1',)]]),
#  ('meie', [['mina', 'P', 'pl n', ('ps1',)]]),
#  ('meiegi', [['mina', 'P', 'pl g', ('ps1',)]]),
#  ('meil', [['mina', 'P', 'pl ad', ('ps1',)]]),
#  ('meile', [['mina', 'P', 'pl all', ('ps1',)]]),
#  ('meilgi', [['mina', 'P', 'pl ad', ('ps1',)]]),
#  ('meist', [['mina', 'P', 'pl el', ('ps1',)]]),
#  ('mida',
#   [['mis', 'P', 'pl p', ('inter_rel',)],
#    ['mis', 'P', 'sg p', ('inter_rel',)]]),
#  ('midagi', [['miski', 'P', 'sg p', ('inter_rel',)]]),
#  ('mille',
#   [['mis', 'P', 'pl g', ('inter_rel',)],
#    ['mis', 'P', 'sg g', ('inter_rel',)]]),
#  ('millega',
#   [['mis', 'P', 'pl kom', ('inter_rel',)],
#    ['mis', 'P', 'sg kom', ('inter_rel',)]]),
#  ('millel',
#   [['mis', 'P', 'pl ad', ('inter_rel',)],
#    ['mis', 'P', 'sg ad', ('inter_rel',)]]),
#  ('millele',
#   [['mis', 'P', 'pl all', ('inter_rel',)],
#    ['mis', 'P', 'sg all', ('inter_rel',)]]),
#  ('milles',
#   [['mis', 'P', 'pl in', ('inter_rel',)],
#    ['mis', 'P', 'sg in', ('inter_rel',)]]),
#  ('millest',
#   [['mis', 'P', 'pl el', ('inter_rel',)],
#    ['mis', 'P', 'sg el', ('inter_rel',)]]),
#  ('millestki', [['miski', 'P', 'sg el', ('inter_rel',)]]),
#  ('milline', [['milline', 'P', 'sg n', ('rel',)]]),
#  ('millise', [['milline', 'P', 'sg g', ('rel',)]]),
#  ('millised', [['milline', 'P', 'pl n', ('rel',)]]),
#  ('milliseid', [['milline', 'P', 'pl p', ('rel',)]]),
#  ('millisena', [['milline', 'P', 'sg es', ('rel',)]]),
#  ('millisesse', [['milline', 'P', 'sg ill', ('rel',)]]),
#  ('millist', [['milline', 'P', 'sg p', ('rel',)]]),
#  ('milliste', [['milline', 'P', 'pl g', ('rel',)]]),
#  ('mind', [['mina', 'P', 'sg p', ('ps1',)]]),
#  ('mingeid', [['mingi', 'P', 'pl p', ('indef',)]]),
#  ('mingi', [['mingi', 'P', 'sg n', ('indef',)]]),
#  ('mingid', [['mingi', 'P', 'pl n', ('indef',)]]),
#  ('mingil', [['mingi', 'P', 'sg ad', ('indef',)]]),
#  ('mingile', [['mingi', 'P', 'sg all', ('indef',)]]),
#  ('mingis', [['mingi', 'P', 'sg in', ('indef',)]]),
#  ('mingisugune', [['mingisugune', 'P', 'sg n', ('indef',)]]),
#  ('mingisuguse', [['mingisugune', 'P', 'sg g', ('indef',)]]),
#  ('mingit', [['mingi', 'P', 'sg p', ('indef',)]]),
#  ('minu', [['mina', 'P', 'sg g', ('ps1',)]]),
#  ('minuga', [['mina', 'P', 'sg kom', ('ps1',)]]),
#  ('minust', [['mina', 'P', 'sg el', ('ps1',)]]),
#  ('mis',
#   [['mis', 'P', 'pl n', ('inter_rel',)],
#    ['mis', 'P', 'sg n', ('inter_rel',)]]),
#  ('miski', [['miski', 'P', 'sg n', ('inter_rel',)]]),
#  ('missugused', [['missugune', 'P', 'pl n', ('inter_rel',)]]),
#  ('missuguste', [['missugune', 'P', 'pl g', ('inter_rel',)]]),
#  ('mitme', [['mitu', 'P', 'sg g', ('indef',)]]),
#  ('mitmed', [['mitu', 'P', 'pl n', ('indef',)]]),
#  ('mitmeid', [['mitu', 'P', 'pl p', ('indef',)]]),
#  ('mitmeks', [['mitu', 'P', 'sg tr', ('indef',)]]),
#  ('mitmel', [['mitu', 'P', 'sg ad', ('indef',)]]),
#  ('mitmelgi', [['mitu', 'P', 'sg ad', ('indef',)]]),
#  ('mitmes', [['mitu', 'P', 'sg in', ('indef',)]]),
#  ('mitmest', [['mitu', 'P', 'sg el', ('indef',)]]),
#  ('mitmesuguseid', [['mitmesugune', 'P', 'pl p', ('indef',)]]),
#  ('mitmesuguste', [['mitmesugune', 'P', 'pl g', ('indef',)]]),
#  ('mitmesugustel', [['mitmesugune', 'P', 'pl ad', ('indef',)]]),
#  ('mitmete', [['mitu', 'P', 'pl g', ('indef',)]]),
#  ('mitu', [['mitu', 'P', 'sg n', ('indef',)]]),
#  ('mitut', [['mitu', 'P', 'sg p', ('indef',)]]),
#  ('mu', [['mina', 'P', 'sg g', ('ps1',)]]),
#  ('muid', [['muu', 'P', 'pl p', ('indef',)]]),
#  ('mul', [['mina', 'P', 'sg ad', ('ps1',)]]),
#  ('mulle', [['mina', 'P', 'sg all', ('ps1',)]]),
#  ('mult', [['mina', 'P', 'sg abl', ('ps1',)]]),
#  ('muu', [['muu', 'P', 'sg n', ('indef',)]]),
#  ('muud', [['muu', 'P', 'pl n', ('indef',)]]),
#  ('muude', [['muu', 'P', 'pl g', ('indef',)]]),
#  ('muudest', [['muu', 'P', 'pl el', ('indef',)]]),
#  ('muudki', [['muu', 'P', 'sg p', ('indef',)]]),
#  ('muul', [['muu', 'P', 'sg ad', ('indef',)]]),
#  ('muus', [['muu', 'P', 'sg in', ('indef',)]]),
#  ('mõlemad', [['mõlema', 'P', 'pl n', ('det',)]]),
#  ('mõlemalt', [['mõlema', 'P', 'sg abl', ('det',)]]),
#  ('mõlemas', [['mõlema', 'P', 'sg in', ('det',)]]),
#  ('mõnda', [['mõni', 'P', 'sg p', ('indef',)]]),
#  ('mõndagi', [['mõni', 'P', 'sg p', ('indef',)]]),
#  ('mõne', [['mõni', 'P', 'sg g', ('indef',)]]),
#  ('mõned', [['mõni', 'P', 'pl n', ('indef',)]]),
#  ('mõnede', [['mõni', 'P', 'pl g', ('indef',)]]),
#  ('mõneks', [['mõni', 'P', 'sg tr', ('indef',)]]),
#  ('mõnelgi', [['mõni', 'P', 'sg ad', ('indef',)]]),
#  ('mõnes', [['mõni', 'P', 'sg in', ('indef',)]]),
#  ('mõnest', [['mõni', 'P', 'sg el', ('indef',)]]),
#  ('mõni', [['mõni', 'P', 'sg n', ('indef',)]]),
#  ('mõnigi', [['mõni', 'P', 'sg n', ('indef',)]]),
#  ('mõningale', [['mõningas', 'P', 'sg all', ('indef',)]]),
#  ('mõningate', [['mõningas', 'P', 'pl g', ('indef',)]]),
#  ('mõningatel', [['mõningas', 'P', 'pl ad', ('indef',)]]),
#  ('nad', [['tema', 'P', 'pl n', ('ps3',)]]),
#  ('need', [['see', 'P', 'pl n', ('dem',)]]),
#  ('needsamad', [['seesama', 'P', 'pl n', ('dem',)]]),
#  ('neid', [['see', 'P', 'pl p', ('dem',)]]),
#  ('neidki', [['tema', 'P', 'pl p', ('ps3',)]]),
#  ('neil', [['tema', 'P', 'pl ad', ('ps3',)]]),
#  ('neile', [['tema', 'P', 'pl all', ('ps3',)]]),
#  ('neilt', [['tema', 'P', 'pl abl', ('ps3',)]]),
#  ('neis', [['tema', 'P', 'pl in', ('ps3',)]]),
#  ('neist', [['tema', 'P', 'pl el', ('ps3',)]]),
#  ('nemad', [['tema', 'P', 'pl n', ('ps3',)]]),
#  ('nemadki', [['tema', 'P', 'pl n', ('ps3',)]]),
#  ('nende', [['tema', 'P', 'pl g', ('ps3',)]]),
#  ('nendega', [['tema', 'P', 'pl kom', ('ps3',)]]),
#  ('nendele', [['tema', 'P', 'pl all', ('ps3',)]]),
#  ('nendest', [['see', 'P', 'pl el', ('dem',)]]),
#  ('niisugune', [['niisugune', 'P', 'sg n', ('dem',)]]),
#  ('niisuguse', [['niisugune', 'P', 'sg g', ('dem',)]]),
#  ('niisugused', [['niisugune', 'P', 'pl n', ('dem',)]]),
#  ('niisuguseid', [['niisugune', 'P', 'pl p', ('dem',)]]),
#  ('niisugust', [['niisugune', 'P', 'sg p', ('dem',)]]),
#  ('niisuguste', [['niisugune', 'P', 'pl g', ('dem',)]]),
#  ('niisugustes', [['niisugune', 'P', 'pl in', ('dem',)]]),
#  ('nood', [['too', 'P', 'pl n', ('dem',)]]),
#  ('oma', [['oma', 'P', 'sg g', ('pos', 'det', 'refl')]]),
#  ('omadega', [['oma', 'P', 'pl kom', ('pos', 'det', 'refl')]]),
#  ('omaenda', [['omaenese', 'P', 'sg g', ('pos',)]]),
#  ('omaenese', [['omaenese', 'P', 'sg g', ('pos',)]]),
#  ('omal', [['oma', 'P', 'sg ad', ('pos', 'det', 'refl')]]),
#  ('paljud', [['palju', 'P', 'pl n', ('indef',)]]),
#  ('paljude', [['palju', 'P', 'pl g', ('indef',)]]),
#  ('paljudele', [['palju', 'P', 'pl all', ('indef',)]]),
#  ('paljus', [['palju', 'P', 'sg in', ('indef',)]]),
#  ('paljustki', [['palju', 'P', 'sg el', ('indef',)]]),
#  ('paljut', [['palju', 'P', 'sg p', ('indef',)]]),
#  ('sa', [['sina', 'P', 'sg n', ('ps2',)]]),
#  ('sama', [['sama', 'P', 'sg n', ('dem',)]]),
#  ('samade', [['sama', 'P', 'pl g', ('dem',)]]),
#  ('samaga', [['sama', 'P', 'sg kom', ('dem',)]]),
#  ('samal', [['sama', 'P', 'sg ad', ('dem',)]]),
#  ('samas', [['sama', 'P', 'sg in', ('dem',)]]),
#  ('samasse', [['sama', 'P', 'sg ill', ('dem',)]]),
#  ('samasuguste', [['samasugune', 'P', 'pl g', ('dem',)]]),
#  ('samasugustele', [['samasugune', 'P', 'pl all', ('dem',)]]),
#  ('seda', [['see', 'P', 'sg p', ('dem',)]]),
#  ('sedagi', [['see', 'P', 'sg p', ('dem',)]]),
#  ('see', [['see', 'P', 'sg n', ('dem',)]]),
#  ('seegi', [['see', 'P', 'sg n', ('dem',)]]),
#  ('seesama', [['seesama', 'P', 'sg n', ('dem',)]]),
#  ('seesugustes', [['seesugune', 'P', 'pl in', ('dem',)]]),
#  ('seks', [['see', 'P', 'sg tr', ('dem',)]]),
#  ('sel', [['see', 'P', 'sg ad', ('dem',)]]),
#  ('selle', [['see', 'P', 'sg g', ('dem',)]]),
#  ('sellega', [['see', 'P', 'sg kom', ('dem',)]]),
#  ('selleks', [['see', 'P', 'sg tr', ('dem',)]]),
#  ('sellel', [['see', 'P', 'sg ad', ('dem',)]]),
#  ('sellele', [['see', 'P', 'sg all', ('dem',)]]),
#  ('selleni', [['see', 'P', 'sg ter', ('dem',)]]),
#  ('selles', [['see', 'P', 'sg in', ('dem',)]]),
#  ('sellest', [['see', 'P', 'sg el', ('dem',)]]),
#  ('selletaoline', [['selletaoline', 'P', 'sg n', ('dem',)]]),
#  ('selline', [['selline', 'P', 'sg n', ('dem',)]]),
#  ('sellise', [['selline', 'P', 'sg g', ('dem',)]]),
#  ('sellised', [['selline', 'P', 'pl n', ('dem',)]]),
#  ('selliseid', [['selline', 'P', 'pl p', ('dem',)]]),
#  ('sellisel', [['selline', 'P', 'sg ad', ('dem',)]]),
#  ('sellisena', [['selline', 'P', 'sg es', ('dem',)]]),
#  ('sellises', [['selline', 'P', 'sg in', ('dem',)]]),
#  ('sellist', [['selline', 'P', 'sg p', ('dem',)]]),
#  ('selliste', [['selline', 'P', 'pl g', ('dem',)]]),
#  ('sellistesse', [['selline', 'P', 'pl ill', ('dem',)]]),
#  ('selsamal', [['seesama', 'P', 'sg ad', ('dem',)]]),
#  ('ses', [['see', 'P', 'sg in', ('dem',)]]),
#  ('sul', [['sina', 'P', 'sg ad', ('ps2',)]]),
#  ('säärane', [['säärane', 'P', 'sg n', ('dem',)]]),
#  ('säärase', [['säärane', 'P', 'sg g', ('dem',)]]),
#  ('sääraseid', [['säärane', 'P', 'pl p', ('dem',)]]),
#  ('säärast', [['säärane', 'P', 'sg p', ('dem',)]]),
#  ('ta', [['tema', 'P', 'sg n', ('ps3',)]]),
#  ('tal', [['tema', 'P', 'sg ad', ('ps3',)]]),
#  ('talle', [['tema', 'P', 'sg all', ('ps3',)]]),
#  ('taolist', [['taoline', 'P', 'sg p', ('dem',)]]),
#  ('te', [['sina', 'P', 'pl n', ('ps2',)]]),
#  ('teda', [['tema', 'P', 'sg p', ('ps3',)]]),
#  ('teid', [['sina', 'P', 'pl p', ('ps2',)]]),
#  ('teie', [['sina', 'P', 'pl g', ('ps2',)]]),
#  ('teil', [['sina', 'P', 'pl ad', ('ps2',)]]),
#  ('teile', [['sina', 'P', 'pl all', ('ps2',)]]),
#  ('teineteise', [['teineteise', 'P', 'sg g', ('rec',)]]),
#  ('teis', [['sina', 'P', 'pl in', ('ps2',)]]),
#  ('teistsugune', [['teistsugune', 'P', 'sg n', ('dem',)]]),
#  ('teistsugused', [['teistsugune', 'P', 'pl n', ('dem',)]]),
#  ('tema', [['tema', 'P', 'sg g', ('ps3',)]]),
#  ('temaga', [['tema', 'P', 'sg kom', ('ps3',)]]),
#  ('temal', [['tema', 'P', 'sg ad', ('ps3',)]]),
#  ('temale', [['tema', 'P', 'sg all', ('ps3',)]]),
#  ('temalgi', [['tema', 'P', 'sg ad', ('ps3',)]]),
#  ('temast', [['tema', 'P', 'sg el', ('ps3',)]]),
#  ('tol', [['too', 'P', 'sg ad', ('dem',)]]),
#  ('tolle', [['too', 'P', 'sg g', ('dem',)]]),
#  ('üksteise', [['üksteise', 'P', 'sg g', ('rec', 'indef')]]),
#  ('üksteisega', [['üksteise', 'P', 'sg kom', ('rec', 'indef')]]),
#  ('üksteisele', [['üksteise', 'P', 'sg all', ('rec', 'indef')]]),
#  ('üksteisest', [['üksteise', 'P', 'sg el', ('rec', 'indef')]]),
#  ('üksteist', [['üksteise', 'P', 'sg p', ('rec', 'indef')]])]

# %%
storage.close()
